# %%
import matplotlib.pyplot as mp
import networkx as nx
import depth_first_search as dfs

# %%
G=nx.Graph()
nodes=['A','B','C','D','E','F','G','H']
G.add_nodes_from(nodes)
edges=[('A','B'),('A','C'),('B','D'),('B','E'),('C','F'),('C','G'),('C','H')]
G.add_edges_from(edges)
nx.draw(G,with_labels=True)
mp.show()

dfs.depth_first_search(G, 'H', 'A', previous_node = None, verbose = True)
# Out:
# Searching in subtree starting at node A
# Searching in subtree starting at node B
# Searching in subtree starting at node D
# Node not found in children, going back
# Searching in subtree starting at node E
# Node not found in children, going back
# Node not found in children, going back
# Searching in subtree starting at node C
# Searching in subtree starting at node F
# Node not found in children, going back
# Searching in subtree starting at node G
# Node not found in children, going back
# Searching in subtree starting at node H
# Found node
# ['A', 'C', 'H']
